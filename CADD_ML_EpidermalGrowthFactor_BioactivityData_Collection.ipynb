# %% [markdown]
# # **Cheminformatis Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Zeinab Alaa
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 2.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Epidermal Growth Factor**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('epidermal growth factor')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references      organism  \
# 0                  []  Homo sapiens
# 1                  []  Mus musculus
# 2                  []  Homo sapiens
# 3                  []  Homo sapiens
# 4                  []  Homo sapiens
# ...               ...           ...
# 1632               []  Homo sapiens
# 1633               []  Homo sapiens
# 1634               []  Homo sapiens
# 1635               []  Homo sapiens
# 1636               []  Homo sapiens
#
#                                               pref_name  score  \
# 0                           Pro-epidermal growth factor   34.0
# 1                      Epidermal growth factor receptor   29.0
# 2                Growth factor receptor-bound protein 7   27.0
# 3     Delta and Notch-like epidermal growth factor-r...   27.0
# 4                      Epidermal growth factor receptor   25.0
# ...                                                 ...    ...
# 1632       Mitochondrial complex I (NADH dehydrogenase)    0.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Epidermal Growth Factor*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL3608'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Epidermal Growth Factor* (CHEMBL3608) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 92  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 93  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 94  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 95  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 96  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id activity_properties assay_chembl_id  \
# 0        110221                  []    CHEMBL675511
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('EpidermalGrowthFactor_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipython-input-3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 92  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 93  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 94  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 95  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 91

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 91  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 92  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 94  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 95  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 96  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id activity_properties assay_chembl_id  \
# 0        110221                  []    CHEMBL675511
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1        CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2         CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3         CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4        CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
# ..                ...                                                ...
# 91      CHEMBL5593705  CS(=O)(=O)c1ccc(NC(=O)c2cc(-c3ccc(Cl)cc3)n(-c3...
# 92         CHEMBL1336  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...
# 94          CHEMBL939     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1
# 95          CHEMBL553         C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1
# 96       CHEMBL545315  C=CC(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2cc1OCCCN...
#
#    standard_value
# 0        100000.0
# 1        100000.0
# 2        100000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('EpidermalGrowthFactor_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('EpidermalGrowthFactor_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1        CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2         CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3         CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4        CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
# ..                ...                                                ...
# 86      CHEMBL5593705  CS(=O)(=O)c1ccc(NC(=O)c2cc(-c3ccc(Cl)cc3)n(-c3...
# 87         CHEMBL1336  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...
# 88          CHEMBL939     COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1
# 89          CHEMBL553         C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1
# 90       CHEMBL545315  C=CC(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2cc1OCCCN...
#
#     standard_value         class
# 0         100000.0      inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('EpidermalGrowthFactor_03_bioactivity_data_curated.csv', index=False)

# %%
! zip EpidermalGrowthFactor.zip *.csv
# Out:
#   adding: epidermalgrowthfactor_01_bioactivity_data_raw.csv (deflated 89%)
#   adding: Epidermal Growth Factor_02_bioactivity_data_preprocessed.csv (deflated 73%)
#   adding: EpidermalGrowthFactor_02_bioactivity_data_preprocessed.csv (deflated 73%)
#   adding: EpidermalGrowthFactor_03_bioactivity_data_curated.csv (deflated 75%)

# %%
! ls -l
# Out:
# total 100
# -rw-r--r-- 1 root root 57149 Feb 14 22:12  epidermalgrowthfactor_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  6197 Feb 14 22:13 'Epidermal Growth Factor_02_bioactivity_data_preprocessed.csv'
# -rw-r--r-- 1 root root  6197 Feb 14 22:14  EpidermalGrowthFactor_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  7022 Feb 14 22:15  EpidermalGrowthFactor_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 12585 Feb 14 22:15  EpidermalGrowthFactor.zip
# drwxr-xr-x 1 root root  4096 Jan 16 14:24  sample_data

# %% [markdown]
# ---
